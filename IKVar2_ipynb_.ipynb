# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0         97        4  ...        397       891  2033    16     9          2
# 1        138        1  ...         46       562  1641     7     2         13
# 2        193        1  ...       1801      1923  1424    18     4         13
# 3         88        8  ...        667       711   454    11     8          6
# 4        114        2  ...        430      1207  1637    17     3         11
#
# ...

# %%
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0          0.5         1   1       0          19    0.3
# 1            587     1          2.5         0  16       1          51    0.6
# 2           1866     0          1.4         0   0       0          30    0.5
# 3           1242     0          1.1         1   0       0          10    0.6
# 4            726     0          2.9         0   0       0          43    0.1
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        134        8  17        387       671  3912    11     2         19
# 1        111        1  17        244      1361  2746    10     4          7
# 2        182        3   0        108      1781  3834    16    11          8
# 3        165        2   1        459      1225  1050    11     1          4
# 4        101        8   0        666       760  1446    17     2          8
#
#    three_g touch_screen  wifi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1500 non-null   int64
#  1   blue           1500 non-null   int64
#  2   clock_speed    1500 non-null   float64
#  3   dual_sim       1500 non-null   int64
#  4   fc             1500 non-null   int64
#  5   four_g         1500 non-null   int64
#  6   int_memory     1500 non-null   int64
#  7   m_dep          1500 non-null   float64
#  8   mobile_wt      1500 non-null   int64
#  9   n_cores        1500 non-null   int64
#  10  pc             1500 non-null   int64
#  11  px_height      1500 non-null   int64
#  12  px_width       1500 non-null   int64
#  13  ram            1500 non-null   int64
#  14  sc_h           1500 non-null   int64
#  15  sc_w           1500 non-null   int64
#  16  talk_time      1500 non-null   int64
#  17  three_g        1500 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     1228.148000     0.496000     1.529467     0.512000     4.164000
# std       439.785748     0.500151     0.811400     0.500023     4.291237
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       840.000000     0.000000     0.700000     0.000000     0.750000
# 50%      1204.000000     0.000000     1.500000     1.000000     3.000000
# 75%      1606.250000     1.000000     2.200000     1.000000     7.000000
# max      1998.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory       m_dep    mobile_wt      n_cores  \
# count  1500.000000  1500.000000  1500.00000  1500.000000  1500.000000
# mean      0.517333    32.426667     0.49540   139.913333     4.486667
# std       0.499866    18.145048     0.28907    35.425845     2.298117
# ...

# %%
df['is_internet'] = ((df['four_g'] == 1) & (df['three_g'] == 1) & (df['wifi'] == 1)).astype(int)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...       891  2033    16     9          2        1
# 1        138        1  ...       562  1641     7     2         13        1
# 2        193        1  ...      1923  1424    18     4         13        1
# 3         88        8  ...       711   454    11     8          6        1
# 4        114        2  ...      1207  1637    17     3         11        1
#
#    touch_screen  wifi price_range  is_internet
# ...

# %%
df_test['is_internet'] = ((df_test['four_g'] == 1) & (df_test['three_g'] == 1) & (df_test['wifi'] == 1)).astype(int)
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0          0.5         1   1       0          19    0.3
# 1            587     1          2.5         0  16       1          51    0.6
# 2           1866     0          1.4         0   0       0          30    0.5
# 3           1242     0          1.1         1   0       0          10    0.6
# 4            726     0          2.9         0   0       0          43    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        134        8  ...        387       671  3912    11     2         19
# 1        111        1  ...        244      1361  2746    10     4          7
# 2        182        3  ...        108      1781  3834    16    11          8
# 3        165        2  ...        459      1225  1050    11     1          4
# 4        101        8  ...        666       760  1446    17     2          8
#
# ...

# %%
df['is_internet'].value_counts()
# Out:
# is_internet
# 0    1108
# 1     392
# Name: count, dtype: int64

# %%
print(1108/(1108+392))
# Out:
# 0.7386666666666667

# %%
df.corr(numeric_only = True)
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000 -0.013861    -0.009412 -0.044354  0.051456
# blue               -0.013861  1.000000     0.007524  0.048207  0.019266
# clock_speed        -0.009412  0.007524     1.000000  0.005869  0.020472
# dual_sim           -0.044354  0.048207     0.005869  1.000000 -0.034806
# fc                  0.051456  0.019266     0.020472 -0.034806  1.000000
# four_g              0.017616  0.010951    -0.051920 -0.030192 -0.024029
# int_memory         -0.010526  0.035693     0.012390  0.007303 -0.020827
# m_dep               0.011010  0.006102    -0.032557 -0.026156 -0.011761
# mobile_wt          -0.009539 -0.023213    -0.002378  0.000473  0.024111
# n_cores            -0.031947  0.060895    -0.012418 -0.027727 -0.039284
# pc                  0.042235 -0.007323    -0.000915 -0.013690  0.651768
# px_height           0.009640 -0.019381    -0.006222 -0.017463  0.017027
# ...

# %%
for x in df.columns:
  print(df[x]. corr(df['price_range']))
# Out:
# 0.20002026783918228
# 0.023877638120064895
# 0.012216172419584889
# 0.02030119050494537
# -0.0008348934489869764
# 0.016723864021500435
# 0.050546998579881694
# -0.0003098497699631282
# -0.031401827863772304
# -0.0057162705917265045
# 0.0019214376004304285
# 0.15467304848385052
# 0.17293917591005403
# 0.9162180608523649
# 0.0397225872738548
# 0.05322067967805603
# 0.002454761862364384
# 0.02452954887934732
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-3218328bccdd> in <cell line: 1>()
#       1 for x in df.columns:
# ----> 2   print(df[x]. corr(df['price_range']))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2725
#    2726         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2727             return nanops.nancorr(
# ...

# %%
corr = df.corr(numeric_only = True)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f2715_row0_col0, #T_f2715_row1_col1, #T_f2715_row2_col2, #T_f2715_row3_col3, #T_f2715_row4_col4, #T_f2715_row5_col5, #T_f2715_row6_col6, #T_f2715_row7_col7, #T_f2715_row8_col8, #T_f2715_row9_col9, #T_f2715_row10_col10, #T_f2715_row11_col11, #T_f2715_row12_col12, #T_f2715_row13_col13, #T_f2715_row14_col14, #T_f2715_row15_col15, #T_f2715_row16_col16, #T_f2715_row17_col17, #T_f2715_row18_col18, #T_f2715_row19_col19, #T_f2715_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2715_row0_col1, #T_f2715_row1_col10, #T_f2715_row1_col11, #T_f2715_row4_col5, #T_f2715_row4_col6, #T_f2715_row4_col17, #T_f2715_row7_col4, #T_f2715_row7_col14, #T_f2715_row8_col12, #T_f2715_row8_col15, #T_f2715_row9_col19, #T_f2715_row10_col6, #T_f2715_row11_col3, #T_f2715_row11_col5, #T_f2715_row13_col7, #T_f2715_row13_col10, #T_f2715_row14_col16, #T_f2715_row15_col8, #T_f2715_row18_col16 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...       891  2033    16     9          2        1
# 1        138        1  ...       562  1641     7     2         13        1
# 2        193        1  ...      1923  1424    18     4         13        1
# 3         88        8  ...       711   454    11     8          6        1
# 4        114        2  ...      1207  1637    17     3         11        1
#
#    touch_screen  wifi price_range  is_internet
# ...

# %%
len(df[(df['price_range'] == 2) & (df['blue'] == 0)]) / len(df[df['price_range'] == 2])
# Out:
# 0.523936170212766

# %%
len(df[(df['talk_time'] < 10) & (df['dual_sim'] == 1)])
# Out:
# 339

# %%
len(df[(df['talk_time'] < 10) & (df['dual_sim'] == 0)])
# Out:
# 291

# %%
339-291
# Out:
# 48

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...       891  2033    16     9          2        1
# 1        138        1  ...       562  1641     7     2         13        1
# 2        193        1  ...      1923  1424    18     4         13        1
# 3         88        8  ...       711   454    11     8          6        1
# 4        114        2  ...      1207  1637    17     3         11        1
#
#    touch_screen  wifi price_range  is_internet
# ...

# %%
df['touch_screen'].value_counts()
# Out:
# touch_screen
# Yes    759
# No     739
# -        2
# Name: count, dtype: int64

# %%
X = df.drop('price_range', axis=1)
y = df['price_range']

# %%
X['touch_screen'] = X['touch_screen'].map({'Yes': 'Yes', '-': 'Yes', 'No': 'No'})

# %%
X['touch_screen'].value_counts()
# Out:
# touch_screen
# Yes    761
# No     739
# Name: count, dtype: int64

# %%
df_test['touch_screen'].value_counts()
# Out:
# touch_screen
# No     253
# Yes    246
# -        1
# Name: count, dtype: int64

# %%
df_test['touch_screen'] = df_test['touch_screen'].map({'Yes': 'Yes', '-': 'Yes', 'No': 'No'})
df_test['touch_screen'].value_counts()
# Out:
# touch_screen
# No     253
# Yes    247
# Name: count, dtype: int64

# %% [markdown]
# OHE

# %%
X = pd.get_dummies(X, columns=['touch_screen'], drop_first=True).astype(int)
df_test = pd.get_dummies(df_test, columns=['touch_screen'], drop_first=True).astype(int)

# %%
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0            0         1   1       0          19      0
# 1            587     1            2         0  16       1          51      0
# 2           1866     0            1         0   0       0          30      0
# 3           1242     0            1         1   0       0          10      0
# 4            726     0            2         0   0       0          43      0
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        134        8  ...        387       671  3912    11     2         19
# 1        111        1  ...        244      1361  2746    10     4          7
# 2        182        3  ...        108      1781  3834    16    11          8
# 3        165        2  ...        459      1225  1050    11     1          4
# 4        101        8  ...        666       760  1446    17     2          8
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn. linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state = 42)
cross_val_score(model, X, y, cv=3, scoring='f1_weighted').mean()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'C': [0.001, 0.01, 0.1, 1, 10]}

# %%
gs = GridSearchCV(model, params, scoring='f1_weighted', cv=3)

# %%
gs.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
gs.best_params_
# Out:
# {'C': 0.01}

# %%
df['ram_resolution'] = df['ram'] * (df['px_height'] + df['px_width'])
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...  2033    16     9          2        1
# 1        138        1  ...  1641     7     2         13        1
# 2        193        1  ...  1424    18     4         13        1
# 3         88        8  ...   454    11     8          6        1
# 4        114        2  ...  1637    17     3         11        1
#
#    touch_screen  wifi  price_range is_internet  ram_resolution
# ...

# %%
df_test['ram_resolution'] = df_test['ram'] * (df_test['px_height'] + df_test['px_width'])
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0            0         1   1       0          19      0
# 1            587     1            2         0  16       1          51      0
# 2           1866     0            1         0   0       0          30      0
# 3           1242     0            1         1   0       0          10      0
# 4            726     0            2         0   0       0          43      0
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        134        8  ...       671  3912    11     2         19        0
# 1        111        1  ...      1361  2746    10     4          7        1
# 2        182        3  ...      1781  3834    16    11          8        0
# 3        165        2  ...      1225  1050    11     1          4        1
# 4        101        8  ...       760  1446    17     2          8        1
#
# ...

# %%
X['ram_resolution'] = X['ram'] * (X['px_height'] + X['px_width'])
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1            2         0   3       1          41      0
# 1           1619     1            1         0   2       1          21      0
# 2           1028     1            2         0   1       1          30      0
# 3           1994     1            0         1   2       1           7      0
# 4           1603     1            0         1   1       1          17      0
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...       891  2033    16     9          2        1
# 1        138        1  ...       562  1641     7     2         13        1
# 2        193        1  ...      1923  1424    18     4         13        1
# 3         88        8  ...       711   454    11     8          6        1
# 4        114        2  ...      1207  1637    17     3         11        1
#
# ...

# %%
gs1 = GridSearchCV(model, params, scoring='f1_weighted', cv=3)

# %%
gs1.fit(X, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
gs1.best_score_
# Out:
# 0.67936670300312

# %%
# !pip install catboost -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 2.4 MB/s eta 0:00:00

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1057     1          2.7         0   3       1          41    0.1
# 1           1619     1          1.9         0   2       1          21    0.4
# 2           1028     1          2.8         0   1       1          30    0.1
# 3           1994     1          0.8         1   2       1           7    0.6
# 4           1603     1          0.5         1   1       1          17    0.5
#
#    mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# 0         97        4  ...  2033    16     9          2        1
# 1        138        1  ...  1641     7     2         13        1
# 2        193        1  ...  1424    18     4         13        1
# 3         88        8  ...   454    11     8          6        1
# 4        114        2  ...  1637    17     3         11        1
#
#    touch_screen  wifi  price_range is_internet  ram_resolution
# ...

# %%
X = df.drop("price_range", axis=1)
y = df["price_range"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   1500 non-null   int64
#  1   blue            1500 non-null   int64
#  2   clock_speed     1500 non-null   float64
#  3   dual_sim        1500 non-null   int64
#  4   fc              1500 non-null   int64
#  5   four_g          1500 non-null   int64
#  6   int_memory      1500 non-null   int64
#  7   m_dep           1500 non-null   float64
#  8   mobile_wt       1500 non-null   int64
#  9   n_cores         1500 non-null   int64
#  10  pc              1500 non-null   int64
#  11  px_height       1500 non-null   int64
#  12  px_width        1500 non-null   int64
#  13  ram             1500 non-null   int64
#  14  sc_h            1500 non-null   int64
#  15  sc_w            1500 non-null   int64
#  16  talk_time       1500 non-null   int64
# ...

# %%
from catboost import CatBoostClassifier

model = CatBoostClassifier(cat_features = [18])

model.fit(X, y)
# Out:
# Learning rate set to 0.08078
# 0:	learn: 1.2653249	total: 70ms	remaining: 1m 9s
# 1:	learn: 1.1773360	total: 80.4ms	remaining: 40.1s
# 2:	learn: 1.0898389	total: 90.1ms	remaining: 30s
# 3:	learn: 1.0161883	total: 101ms	remaining: 25.1s
# 4:	learn: 0.9506571	total: 114ms	remaining: 22.8s
# 5:	learn: 0.9026824	total: 125ms	remaining: 20.7s
# 6:	learn: 0.8564705	total: 135ms	remaining: 19.1s
# 7:	learn: 0.8030687	total: 145ms	remaining: 18s
# 8:	learn: 0.7606828	total: 155ms	remaining: 17.1s
# 9:	learn: 0.7152340	total: 165ms	remaining: 16.4s
# 10:	learn: 0.6826416	total: 175ms	remaining: 15.8s
# 11:	learn: 0.6534063	total: 186ms	remaining: 15.3s
# 12:	learn: 0.6247393	total: 198ms	remaining: 15s
# 13:	learn: 0.5975295	total: 213ms	remaining: 15s
# 14:	learn: 0.5729156	total: 223ms	remaining: 14.7s
# 15:	learn: 0.5496679	total: 233ms	remaining: 14.3s
# 16:	learn: 0.5307989	total: 244ms	remaining: 14.1s
# 17:	learn: 0.5093865	total: 254ms	remaining: 13.8s
# ...

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test['is_internet'] = ((df_test['four_g'] == 1) & (df_test['three_g'] == 1) & (df_test['wifi'] == 1)).astype(int)

# %%
df_test['ram_resolution'] = df_test['ram'] * (df_test['px_height'] + df_test['px_width'])

# %%
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0          0.5         1   1       0          19    0.3
# 1            587     1          2.5         0  16       1          51    0.6
# 2           1866     0          1.4         0   0       0          30    0.5
# 3           1242     0          1.1         1   0       0          10    0.6
# 4            726     0          2.9         0   0       0          43    0.1
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        134        8  ...       671  3912    11     2         19        0
# 1        111        1  ...      1361  2746    10     4          7        1
# 2        182        3  ...      1781  3834    16    11          8        0
# 3        165        2  ...      1225  1050    11     1          4        1
# 4        101        8  ...       760  1446    17     2          8        1
#
#    touch_screen  wifi is_internet  ram_resolution
# ...

# %%
pred = model.predict(df_test)

pred[:10]
# Out:
# array([[3],
#        [2],
#        [3],
#        [0],
#        [0],
#        [1],
#        [3],
#        [2],
#        [3],
#        [2]])

# %%
df_test['price_range'] = pred
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1379     0          0.5         1   1       0          19    0.3
# 1            587     1          2.5         0  16       1          51    0.6
# 2           1866     0          1.4         0   0       0          30    0.5
# 3           1242     0          1.1         1   0       0          10    0.6
# 4            726     0          2.9         0   0       0          43    0.1
#
#    mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# 0        134        8  ...  3912    11     2         19        0
# 1        111        1  ...  2746    10     4          7        1
# 2        182        3  ...  3834    16    11          8        0
# 3        165        2  ...  1050    11     1          4        1
# 4        101        8  ...  1446    17     2          8        1
#
#    touch_screen  wifi  is_internet ram_resolution  price_range
# ...

# %%
df_test[['price_range']].to_csv("result.csv", index=False)
